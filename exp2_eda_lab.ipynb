# %% [markdown]
# <a href="https://colab.research.google.com/github/riyastanley/Exploratory-Data-Analysis-/blob/main/exp2_eda_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv("/1000 Sales Records.csv")

# %%
df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
df.head(7)
# Out:
#                          Region  Country   Item Type Sales Channel  \
# 0  Middle East and North Africa    Libya   Cosmetics       Offline
# 1                 North America   Canada  Vegetables        Online
# 2  Middle East and North Africa    Libya   Baby Food       Offline
# 3                          Asia    Japan      Cereal       Offline
# 4            Sub-Saharan Africa     Chad      Fruits       Offline
# 5                        Europe  Armenia      Cereal        Online
# 6            Sub-Saharan Africa  Eritrea      Cereal        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# ...

# %%
df.head(10)
# Out:
#                               Region     Country   Item Type Sales Channel  \
# 0       Middle East and North Africa       Libya   Cosmetics       Offline
# 1                      North America      Canada  Vegetables        Online
# 2       Middle East and North Africa       Libya   Baby Food       Offline
# 3                               Asia       Japan      Cereal       Offline
# 4                 Sub-Saharan Africa        Chad      Fruits       Offline
# 5                             Europe     Armenia      Cereal        Online
# 6                 Sub-Saharan Africa     Eritrea      Cereal        Online
# 7                             Europe  Montenegro     Clothes       Offline
# 8  Central America and the Caribbean     Jamaica  Vegetables        Online
# 9              Australia and Oceania        Fiji  Vegetables       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
df['Country'].dtype
# Out:
# dtype('O')

# %%
df['Unit Price'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
total_records = len(df)
print(total_records)
# Out:
# 1000

# %%
print(df.columns)
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price    Unit Cost  Total Revenue  \
# count  1.000000e+03  1000.000000  1000.00000  1000.000000   1.000000e+03
# mean   5.496813e+08  5053.988000   262.10684   184.965110   1.327322e+06
# std    2.571334e+08  2901.375317   216.02106   175.289311   1.486515e+06
# min    1.029280e+08    13.000000     9.33000     6.920000   2.043250e+03
# 25%    3.280740e+08  2420.250000    81.73000    56.670000   2.811919e+05
# 50%    5.566097e+08  5184.000000   154.06000    97.440000   7.549392e+05
# 75%    7.696945e+08  7536.750000   421.89000   263.330000   1.733503e+06
# max    9.955298e+08  9998.000000   668.27000   524.960000   6.617210e+06
#
#          Total Cost  Total Profit
# count  1.000000e+03  1.000000e+03
# mean   9.361192e+05  3.912026e+05
# std    1.162571e+06  3.836402e+05
# min    1.416750e+03  5.326100e+02
# 25%    1.649319e+05  9.837612e+04
# 50%    4.647261e+05  2.772260e+05
# 75%    1.141750e+06  5.484568e+05
# ...

# %%
df.max()
# Out:
# Region            Sub-Saharan Africa
# Country                     Zimbabwe
# Item Type                 Vegetables
# Sales Channel                 Online
# Order Priority                     M
# Order Date                  9/8/2015
# Order ID                   995529830
# Ship Date                   9/9/2016
# Units Sold                      9998
# Unit Price                    668.27
# Unit Cost                     524.96
# Total Revenue             6617209.54
# Total Cost                 5204978.4
# Total Profit              1726181.36
# dtype: object

# %%
df.mean(numeric_only=True)
# Out:
# Order ID         5.496813e+08
# Units Sold       5.053988e+03
# Unit Price       2.621068e+02
# Unit Cost        1.849651e+02
# Total Revenue    1.327322e+06
# Total Cost       9.361192e+05
# Total Profit     3.912026e+05
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# Order ID         1.029280e+08
# Units Sold       1.300000e+01
# Unit Price       9.330000e+00
# Unit Cost        6.920000e+00
# Total Revenue    2.043250e+03
# Total Cost       1.416750e+03
# Total Profit     5.326100e+02
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# Order ID         9.955298e+08
# Units Sold       9.998000e+03
# Unit Price       6.682700e+02
# Unit Cost        5.249600e+02
# Total Revenue    6.617210e+06
# Total Cost       5.204978e+06
# Total Profit     1.726181e+06
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Order ID         5.566097e+08
# Units Sold       5.184000e+03
# Unit Price       1.540600e+02
# Unit Cost        9.744000e+01
# Total Revenue    7.549392e+05
# Total Cost       4.647261e+05
# Total Profit     2.772260e+05
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# Order ID         2.571334e+08
# Units Sold       2.901375e+03
# Unit Price       2.160211e+02
# Unit Cost        1.752893e+02
# Total Revenue    1.486515e+06
# Total Cost       1.162571e+06
# Total Profit     3.836402e+05
# dtype: float64

# %%
df.sample()
# Out:
#     Region Country  Item Type Sales Channel Order Priority Order Date  \
# 901   Asia   Japan  Cosmetics        Online              L   1/6/2016
#
#       Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 901  453569972  2/19/2016         289       437.2     263.33       126350.8
#
#      Total Cost  Total Profit
# 901    76102.37      50248.43

# %%
df.dropna()
# Out:
#                            Region               Country   Item Type  \
# 0    Middle East and North Africa                 Libya   Cosmetics
# 1                   North America                Canada  Vegetables
# 2    Middle East and North Africa                 Libya   Baby Food
# 3                            Asia                 Japan      Cereal
# 4              Sub-Saharan Africa                  Chad      Fruits
# ..                            ...                   ...         ...
# 995  Middle East and North Africa            Azerbaijan      Snacks
# 996                        Europe               Georgia   Baby Food
# 997  Middle East and North Africa  United Arab Emirates  Vegetables
# 998                        Europe               Finland   Household
# 999                        Europe              Portugal      Cereal
#
#     Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0         Offline              M  10/18/2014  686800706  10/31/2014
# ...

# %%
first_50 = df.head(50)
print(first_50.mean(numeric_only=True))
# Out:
# Order ID         4.844509e+08
# Units Sold       5.037020e+03
# Unit Price       2.611640e+02
# Unit Cost        1.881152e+02
# Total Revenue    1.322732e+06
# Total Cost       9.690889e+05
# Total Profit     3.536435e+05
# dtype: float64

# %%
print(df['Units Sold'].mean())
# Out:
# 5053.988

# %%
country=df.groupby(['Country'])

# %%
country.mean(numeric_only=True)
# Out:
#                   Order ID   Units Sold  Unit Price   Unit Cost  \
# Country
# Afghanistan   6.586300e+08  3775.166667  149.095000   78.706667
# Albania       6.899045e+08  5678.875000  204.493750  137.526250
# Algeria       2.168614e+08  6955.800000  312.834000  239.334000
# Andorra       5.826290e+08  4592.571429  269.137143  195.065714
# Angola        3.838087e+08  5118.125000  335.386250  242.013750
# ...                    ...          ...         ...         ...
# Vatican City  5.518604e+08  4104.750000  115.842500   64.000000
# Vietnam       5.138378e+08  4869.142857  340.467143  245.387143
# Yemen         5.527234e+08  5316.500000  401.050000  284.481667
# Zambia        5.958717e+08  5525.000000  132.305000   83.170000
# Zimbabwe      5.543018e+08  5078.900000  156.435000  117.988000
#
#               Total Revenue    Total Cost   Total Profit
# Country
# Afghanistan    4.739315e+05  2.463637e+05  227567.850000
# Albania        1.213737e+06  8.208539e+05  392883.542500
# ...

# %%
df_sub = df[ df['Units Sold'] > 9000]
print(df_sub)
# Out:
#                                 Region                   Country  \
# 4                   Sub-Saharan Africa                      Chad
# 5                               Europe                   Armenia
# 22        Middle East and North Africa                   Algeria
# 25   Central America and the Caribbean                   Grenada
# 28                  Sub-Saharan Africa                      Chad
# ..                                 ...                       ...
# 974       Middle East and North Africa                    Jordan
# 975  Central America and the Caribbean                    Panama
# 976                 Sub-Saharan Africa  Central African Republic
# 997       Middle East and North Africa      United Arab Emirates
# 998                             Europe                   Finland
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 4           Fruits       Offline              H   8/16/2011  645713555
# ...

# %%
print(df.loc[10:20,['Item Type','Ship Date','Unit Price']])
# Out:
#           Item Type   Ship Date  Unit Price
# 10          Clothes   1/19/2016      109.28
# 11           Snacks   3/18/2010      152.58
# 12        Household  12/22/2016      668.27
# 13        Cosmetics    1/5/2016      437.20
# 14           Fruits    2/6/2011        9.33
# 15          Clothes   7/22/2010      109.28
# 16  Office Supplies   5/12/2016      651.21
# 17        Beverages    8/7/2012       47.45
# 18          Clothes   10/3/2014      109.28
# 19        Household    9/8/2012      668.27
# 20           Snacks  10/15/2012      152.58

# %%
print(df_sub.iloc[10:20,[0, 1, 2, 5]])
# Out:
#                                 Region                   Country  \
# 72                  Sub-Saharan Africa                Cape Verde
# 79                       North America  United States of America
# 91   Central America and the Caribbean               El Salvador
# 110              Australia and Oceania                     Tonga
# 133                             Europe                   Germany
# 137                               Asia                Uzbekistan
# 146                             Europe                    Serbia
# 171                             Europe                Luxembourg
# 172                 Sub-Saharan Africa                 Swaziland
# 195       Middle East and North Africa                   Lebanon
#
#            Item Type  Order Date
# 72         Beverages  10/23/2013
# 79   Office Supplies    6/9/2017
# 91           Clothes    8/7/2010
# 110        Beverages   1/27/2010
# 133        Baby Food  11/13/2015
# 137    Personal Care   2/12/2013
# ...

# %%
print(df.iloc[0])
# Out:
# Region            Middle East and North Africa
# Country                                  Libya
# Item Type                            Cosmetics
# Sales Channel                          Offline
# Order Priority                               M
# Order Date                          10/18/2014
# Order ID                             686800706
# Ship Date                           10/31/2014
# Units Sold                                8446
# Unit Price                               437.2
# Unit Cost                               263.33
# Total Revenue                        3692591.2
# Total Cost                          2224085.18
# Total Profit                        1468506.02
# Name: 0, dtype: object

# %%
print(df.iloc[:, 0])
# Out:
# 0      Middle East and North Africa
# 1                     North America
# 2      Middle East and North Africa
# 3                              Asia
# 4                Sub-Saharan Africa
#                    ...
# 995    Middle East and North Africa
# 996                          Europe
# 997    Middle East and North Africa
# 998                          Europe
# 999                          Europe
# Name: Region, Length: 1000, dtype: object

# %%
print(df.iloc[0:5])
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
print(df.iloc[0:4, 0:4])
# Out:
#                          Region Country   Item Type Sales Channel
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
